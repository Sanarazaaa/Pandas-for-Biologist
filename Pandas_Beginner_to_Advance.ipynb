# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanarazaaa/Pandas-for-Biologist/blob/main/Pandas_Beginner_to_Advance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
# create a series
import pandas as pd
# From a list
data_list = [1, 2, 3, 4]
series_from_list = pd.Series(data_list)
print(series_from_list)

# From a dictionary
data_dict = {'a': 1, 'b': 2, 'c': 3}
series_from_dict = pd.Series(data_dict)
print(series_from_dict)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
# create a dataframe
# From a dictionary of lists
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
# view data
print(df.head())
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
# access columns
print(df['Name'])

# %%
# access rows
print(df.iloc[0])  # First row
print(df.iloc[1:3])  # Rows from index 1 to 2
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
#  filter data based on a condition
# Filter rows where Age is greater than 28
filtered_df = df[df['Age'] > 28]
print(filtered_df)
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
# adding new column
df['Salary'] = [50000, 60000, 70000]
print(df)
# Out:
#       Name  Age         City  Salary
# 0    Alice   25     New York   50000
# 1      Bob   30  Los Angeles   60000
# 2  Charlie   35      Chicago   70000

# %%
# Get a summary of statistics for numerical columns
print(df.describe())
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
# Example: Group by City and calculate average Age
grouped = df.groupby('City')['Age'].mean()
print(grouped)
# Out:
# City
# Chicago        35.0
# Los Angeles    30.0
# New York       25.0
# Name: Age, dtype: float64

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'],
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# The list of row labels used in a DataFrame is known as an Index.
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# # Series
#
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
pd.Series([1, 2, 3, 4, 5])

# %%
df = pd.read_csv('/Cell_Observations.csv')
print(df.to_string())
# Out:
#          ID  Experiment_ID  X_position_of_cell  Y_position_of_cell            Timestamp  Cell_size
# 0         1              5               52.08               18.83  2023-06-15 22:45:25       7.92
# 1         2              2               86.91               51.58  2024-08-18 09:00:12       8.61
# 2         3              5               90.95               51.13  2023-06-29 03:38:42       7.00
# 3         4             10               12.69               12.69  2023-12-28 17:51:12       2.25
# 4         5              7                6.57               38.46  2024-02-15 05:11:00       3.41
# 5         6              2               92.45               32.83  2023-09-01 10:24:34       1.35
# 6         7              3               87.36               83.81  2022-11-26 15:51:22       6.04
# 7         8              3               75.84               66.33  2023-05-12 05:46:52       2.74
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
print(df.info()) # enteries are rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  10000 non-null  int64
#  1   Experiment_ID       10000 non-null  int64
#  2   X_position_of_cell  10000 non-null  float64
#  3   Y_position_of_cell  10000 non-null  float64
#  4   Timestamp           10000 non-null  object
#  5   Cell_size           10000 non-null  float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 468.9+ KB
# None

# %% [markdown]
# # ***Data Cleaning***

# %%
# %who
# Out:
# data	 data_dict	 data_list	 df	 pd	 series_from_dict	 series_from_list

# %%
df.rename(columns={'Cell_size': 'Size_of_Cell'}, inplace=True)
# (df.tostring()) ---> converts DataFrame into a string representation and prints it, regardless of its size.

# %%
df.dropna(inplace = True) # dropna(): Removes rows or columns with missing data (NaN values).
print(df.to_string()) #inplace=True: Makes the changes directly to the DataFrame (df) instead of returning a new DataFrame.
# Out:
#          ID  Experiment_ID  X_position_of_cell  Y_position_of_cell            Timestamp  Size_of_Cell
# 0         1              5               52.08               18.83  2023-06-15 22:45:25          7.92
# 1         2              2               86.91               51.58  2024-08-18 09:00:12          8.61
# 2         3              5               90.95               51.13  2023-06-29 03:38:42          7.00
# 3         4             10               12.69               12.69  2023-12-28 17:51:12          2.25
# 4         5              7                6.57               38.46  2024-02-15 05:11:00          3.41
# 5         6              2               92.45               32.83  2023-09-01 10:24:34          1.35
# 6         7              3               87.36               83.81  2022-11-26 15:51:22          6.04
# 7         8              3               75.84               66.33  2023-05-12 05:46:52          2.74
# ...

# %%
df.fillna(130, inplace = True)
# Replace NULL values with the number 130

# %%
# Check for duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
print(df.isnull().sum())
# Out:
# ID                    0
# Experiment_ID         0
# X_position_of_cell    0
# Y_position_of_cell    0
# Timestamp             0
# Size_of_Cell          0
# dtype: int64

# %%
# verify datatypes
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
# check for outliers
print(df[['X_position_of_cell', 'Y_position_of_cell']].describe())
# Out:
#        X_position_of_cell  Y_position_of_cell
# count        10000.000000        10000.000000
# mean            49.648542           50.019172
# std             28.898272           28.901853
# min              0.010000            0.030000
# 25%             24.535000           25.077500
# 50%             49.160000           49.990000
# 75%             74.522500           74.905000
# max             99.980000           99.990000

# %%
# Decide whether to keep or remove outliers based on domain knowledge.
import matplotlib.pyplot as plt
df[['X_position_of_cell']].boxplot()
plt.show()

# %%
# If the value in X_position_of_cell is a unique identifier, confirm its uniqueness:
print(df['X_position_of_cell'].is_unique)
# Out:
# False

# %%
df['Date'] = df['Timestamp'].dt.date
df['Hour'] = df['Timestamp'].dt.hour

# %%
# save the clean structure
df.to_csv('cleaned_data.csv', index=False)

# %%
df.corr()

# %% [markdown]
# The number varies from **-1 to 1.**
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
